# %% [markdown]
# # Visualizing Downscaled Climate Projections in the U.S.
#
# ## Haley Crim and Rey Lautenschlager

# %%
pip install cenpy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 38.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 13.8 MB/s eta 0:00:00
# ...
#   DEPRECATION: Building 'cenpy' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'cenpy'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for cenpy: filename=cenpy-1.0.1-py3-none-any.whl size=30126 sha256=3e336870f49767a3eddb2239fceb9c1692c9b71e940e189c99b478184300f420
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f0/90/02/6460d91fa1c10cf77a1c4140e62ddb8cefc80c2cf1af393671
# Successfully built cenpy
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import geopandas as gpd
import cenpy as c
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File /srv/conda/envs/notebook/lib/python3.12/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
# ...

# %%
# Load the CSV into a DataFrame
df = pd.read_csv('Atlas_1.5.csv')

# Preview the first few rows
df.head()
# Out:
#    OBJECTID     County name State name State abbreviation  FIPS  \
# 0         1  Autauga County    Alabama                 AL  1001
# 1         2  Baldwin County    Alabama                 AL  1003
# 2         3  Barbour County    Alabama                 AL  1005
# 3         4     Bibb County    Alabama                 AL  1007
# 4         5   Blount County    Alabama                 AL  1009
#
#    Precip Above 99th pctl  Precip 1-day max  Precip 5-year max  \
# 0                8.866368          1.204632           0.560895
# 1               10.447559          3.454147           1.104216
# 2               10.930474          0.800702           0.499965
# 3               10.956795          2.631909           1.330318
# 4               18.316114          6.689886           6.570682
#
#    Temperature average  Temp max 1-day  ...  Temp Days 95 F  Temp mean summer  \
# 0             1.732316        1.543474  ...       14.359526          1.604421
# ...
